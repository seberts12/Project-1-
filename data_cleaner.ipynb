# %%
import pandas as pd

# %%
def data_clean(my_df):
    tickers = list(data.iloc[54:58, 0])
    quantity = list(data.loc[54:58, "Unnamed: 2"])
    return tickers, quantity

# %%
data_portfolio = pd.read_csv("2022-06-27-AccountStatement.csv")

data_portfolio
# Out:
#    Account Statement for 454699288TDA (seberts12) since 5/28/22 through 6/26/22  \
# 0                                                 NaN
# 1                                        Cash Balance
# 2                                                DATE
# 3                                           5/28/2022
# 4                                           5/29/2022
# ..                                                ...
# 70                                 Stock Buying Power
# 71                                Option Buying Power
# 72                      Equity Commissions & Fees YTD
# 73                     Futures Commissions & Fees YTD
# 74                       Total Commissions & Fees YTD
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2          TIME       TYPE      REF #
# 3      22:00:00        BAL        NaN
# 4      22:00:00        BAL        NaN
# ..          ...        ...        ...
# ...

# %%
tickers, quantity = data_clean(data_portfolio)

# %%
display(tickers)
display(quantity)
# Out:
# ['QQQ', 'CANO', 'PYPL', 'CCORF']
# ['20', '107', '5', '100', nan]
